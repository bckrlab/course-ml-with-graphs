# %% [markdown]
# # Relational Deep Learning

# %% [markdown]
# ## Relational Tables to Graphs

# %% [markdown]
# Given the tables:
#
# - Users
#
#     | user_id |
#     | ------- |
#     | U1      |
#     | U2      |
#
# - Products
#
#     | product_id |
#     | ---------- |
#     | P1         |
#     | P2         |
#
# - Sales
#
#     | sale_id | user_id | product_id | price |
#     | ------- | ------- | ---------- | ----- |
#     | S1      | U1      | P1         | 20    |
#     | S2      | U1      | P2         | 80    |
#     | S3      | U2      | P1         | 15    |
#
# 1. Construct the relational entity graph. What are the nodes and edges?
#
# 1. What node types and edge types exist?
#
# 1. Where does the `price` live in the graph representation?

# %% [markdown]
# # Graph Generation

# %% [markdown]
# ## Graph Generative Models

# %% [markdown]
# Assume that we are given a set of graphs $\{x_i\}$ sampled from $p_{\text{data}}(x)$ (which is unknown to us) and we want to generate more graphs similar to what we have.
#
# 1. What do we learn from the data in this case?
#
# 1. What is the objective that we maximize/minimize?
#
# 1. After training, how do we generate a new graph from the model?
#
# 1. In our case each $x$ is a graph. What extra difficulty appears when $x$ is a graph rather than a fixed-size vector? Name one issue.

# %% [markdown]
# # Geometric Deep Learning

# %% [markdown]
# We want to predict a chemical property of a molecule (e.g., solubility in water). We have a set of molecules represented with graphs. For each molecule, we also know the coordinates of the atoms in that molecule.
#
# We train a GNN on these graphs and obtain good predictive performance.
#
# Given that, answer the following:
#
# 1. What happens if we rotate every molecule in the test set by 90°?
#
#     (a) Does the true solubility of the molecules change?
#
#     (b) Do the predictions of a regular GNN change? Why is this a problem?
#
# 1. Would augmenting the training set with randomly rotated molecules help? Why or why not?
#
# 1. How do geometric GNNs solve this issue?
